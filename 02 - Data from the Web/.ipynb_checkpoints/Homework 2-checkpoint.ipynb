# %%
# Import libraries
import requests, json
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import difflib

# %% [markdown]
# ## Functions required for scraping the data
#
# * For the QS International Rankings, we have to go to the urls of every university (easily accessible via the unique nid) to extract the data for each university. That can be seen in the `import_details_qs` function. We merge the details obtained about the international student and faculty ratios with the original `DataFrame`
#
# * For the Time Higher Education example, there are already `json` files available, as seen from the Postman Interceptor and hence we can directly use all of them.

# %%
def import_json(url):
    r = requests.get(url)
    universityJson = json.loads(r.text)
    top200 = pd.DataFrame(universityJson['data'])[:200] #import the top200 universities
    return top200

def import_details_qs(top200): #requires special handling as international stud/fac data not available
    Intl_Data = pd.DataFrame()
    for index, row in top200.iterrows():
        nid = row['nid']
        Intl_link = 'https://www.topuniversities.com/node/'+str(nid)
        rIntl = requests.get(Intl_link)
        
        if rIntl.ok:
            page_body = rIntl.text
            soup = BeautifulSoup(page_body, 'html.parser')
            #Total n - faculty
            try :
                t_faculty = soup.find_all('div', class_='total faculty')[0].find('div', class_='number').text
                tot_fac_value = int(t_faculty[1:-1].replace(',',''))
            except:
                tot_fac_value = 0
            #Total n - international faculty
            try:
                t_interfaculty = soup.find_all('div',class_='inter faculty')[0].find('div',class_='number').text
                tot_intfac_value = int(t_interfaculty[1:-1].replace(',',''))
            except:
                tot_intfac_value = 0
            #Total n - students
            try:
                t_stud = soup.find_all('div', class_='total student')[0].find('div', class_='number').text
                tot_stud_value = int(t_stud[1:-1].replace(',',''))
            except:
                tot_stud_value = 0
            #Total n - international students
            try:
                t_intstud = soup.find_all('div', class_='total inter')[0].find('div', class_='number').text
                tot_intstud_value = int(t_intstud[1:-1].replace(',',''))
            except:
                tot_intstud_value = 0
            IntlDF = pd.DataFrame({'nid' : [nid],'total_faculty_members' : [tot_fac_value], 'international_faculty_members' : [tot_intfac_value], 'total_students' : [tot_stud_value], 'international_students' : [tot_intstud_value]})
            Intl_Data = Intl_Data.append(IntlDF, ignore_index=True)
    return Intl_Data

def import_details_times(top200):
    locationData = pd.DataFrame()
    for index, row in top200.iterrows():
        nid = row['nid']
        locationLink = 'https://www.timeshighereducation.com/sites/default/files/institution_markers/gmap_'+str(nid)+'.json'
        rLocation = requests.get(locationLink)
        if rLocation.ok:
            locationJson = json.loads(rLocation.text)
            locationDF = pd.DataFrame(locationJson)
            locationData = locationData.append(locationDF, ignore_index=True)
    return locationData

# %% [markdown]
# ## QS International Rankings

# %%
# %%time
top200_qs = import_json('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt?_=1508492427994')
data_qs = import_details_qs(top200_qs)
# Out:
# CPU times: user 57.5 s, sys: 1.12 s, total: 58.6 s
# Wall time: 1min 40s

# %%
top200_qs_full = pd.merge(top200_qs, data_qs, on='nid')
top200_qs_full.rename(columns={'title':'name'})
top200_qs_full.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
# ...

# %% [markdown]
# ##  Which are the best universities in terms of ratio between faculty members and students?

# %%
top200_qs_full['fac_stud_ratio'] = top200_qs_full['total_students']/top200_qs_full['total_faculty_members']

# %%
top200_qs_full.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
# ...

# %%
#The `stats_student_staff_ratio` values seem to be stored as a string so let's fix it
top200_qs_full['fac_stud_ratio'] = top200_qs_full['total_students']/top200_qs_full['total_faculty_members']
#Sort based on the ratio (lower better) and take the top 10
topfacultyratio = top200_qs_full.sort_values('fac_stud_ratio',ascending=True)[:10][['QSname','fac_stud_ratio']]

topfacultyratio[:10].plot(x='QSname',y='fac_stud_ratio', kind='bar')
plt.show()

# %%
# Which are the best universities in term of: (b) ratio of international students

top200_qs_full['ratio_int_student'] = top200_qs_full['international_students']/top200_qs_full['total_students']
# Sort based on the ratio (higher better) and take top 10
topintlstudents = top200_qs_full.sort_values('ratio_int_student',ascending=False)[:10][['QSname','ratio_int_student']]

topintlstudents[:10].plot(x='QSname',y='ratio_int_student', kind='bar')
plt.show()

# %%
# Answer the previous question aggregating the data by (c) country
# Group student staff ratio by country and take the mean
topFacultyRatioCountries = top200_qs_full.groupby('country')['fac_stud_ratio'].mean()
# Take the top ten (lower better)
topFacultyRatioCountries = topFacultyRatioCountries.sort_values(ascending=True)[:10]
topFacultyRatioCountries.plot(x='country',kind='bar')
plt.show()

# %%
# Answer the previous question aggregating the data by (c) country
topFacultyRatioCountries = top200_qs_full.groupby('country')['ratio_int_student'].mean()
# Take the bottom ten (higher better)
topFacultyRatioCountries = topFacultyRatioCountries.sort_values(ascending=False)[:10]
topFacultyRatioCountries.plot(x='country',kind='bar')
plt.show()

# %% [markdown]
# ## Times Higher Education International Rankings

# %%
# %%time
top200_times = import_json('https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json')
locdata_times = import_details_times(top200_times)
# Out:
# CPU times: user 6.11 s, sys: 394 ms, total: 6.5 s
# Wall time: 24.2 s

# %%
locdata_times = locdata_times.rename(columns={'title':'TimesName'})
top200_times = top200_times.rename(columns={'name':'TimesName'})
top200_times_full = pd.merge(top200_times, locdata_times, on='TimesName')

# %%
top200_times_full.head()
# Out:
#                                       aliases        location member_level  \
# 0                        University of Oxford  United Kingdom            0
# 1                     University of Cambridge  United Kingdom            0
# 2  California Institute of Technology caltech   United States            0
# 3                         Stanford University   United States           11
# 4       Massachusetts Institute of Technology   United States            0
#
#                                TimesName     nid rank rank_order  \
# 0                   University of Oxford     468    1         10
# 1                University of Cambridge     470    2         20
# 2     California Institute of Technology  128779   =3         30
# 3                    Stanford University     467   =3         40
# 4  Massachusetts Institute of Technology     471    5         50
#
#       record_type scores_citations scores_citations_rank  \
# 0  master_account             99.1                    15
# ...

# %% [markdown]
# ##  Which are the best universities in terms of ratio between faculty members and students?

# %%
#The `stats_student_staff_ratio` values seem to be stored as a string so let's fix it
top200_times_full.stats_student_staff_ratio = top200_times_full.stats_student_staff_ratio.apply(pd.to_numeric)
#Sort based on the ratio (lower better) and take the top 10
topfacultyratio = top200_times_full.sort_values('stats_student_staff_ratio',ascending=True)[:10s][['TimesName','stats_student_staff_ratio']]

topfacultyratio[:10].plot(x='TimesName',y='stats_student_staff_ratio', kind='bar')
plt.show()

# %%
# Which are the best universities in term of: (b) ratio of international students
# The stats_pc_intl_students is stored as percentage, let's make it ratio
def p2f(x):
    if type(x) == str:
        return float(x.strip('%'))/100
    elif type(x) == float:
        return x
    else:
        raise('Not correct type')

top200_times_full.stats_pc_intl_students = top200_times_full.stats_pc_intl_students.apply(p2f)
# Sort based on the ratio (higher better) and take top 10
topintlstudents = top200_times_full.sort_values('stats_pc_intl_students',ascending=False)[:10][['TimesName','stats_pc_intl_students']]

topintlstudents[:10].plot(x='TimesName',y='stats_pc_intl_students', kind='bar')
plt.show()

# %%
# Answer the previous question aggregating the data by (c) country
# Group student staff ratio by country and take the mean
topFacultyRatioCountries = top200_times_full.groupby('country')['stats_student_staff_ratio'].mean()
# Take the top ten (lower better)
topFacultyRatioCountries = topFacultyRatioCountries.sort_values(ascending=True)[:10]
topFacultyRatioCountries.plot(x='country',kind='bar')
plt.show()

# %%
# And the same for the international student ratio
topInternationalStudentCountries = top200_times_full.groupby('country')['stats_pc_intl_students'].mean()
# Take the top ten (higher better)
topInternationalStudentCountries = topInternationalStudentCountries.sort_values(ascending=False)[:10]
topInternationalStudentCountries.plot(x='country',kind='bar')
plt.show()

# %%
# We do the same by region (locality)
topFacRatLoc = top200_times_full.groupby(['country','locality'])['stats_student_staff_ratio'].mean()
topFacRatLoc = topFacRatLoc.sort_values(ascending=True)[:10]
topIntlStudentLoc = top200_times_full.groupby(['country','locality'])['stats_pc_intl_students'].mean()
topIntlStudentLoc = topIntlStudentLoc.sort_values(ascending=False)[:10]
topFacRatLoc.plot(x=['country','locality'],kind='bar')
plt.show()

# %%
topIntlStudentLoc.plot(x=['country','locality'],kind='bar')
plt.show()

# %% [markdown]
# ## Merging both datasets by name

# %%
top200_qs_full = top200_qs_full.rename(columns={'title':'QSname'})
top200_qs_full.head()
# Out:
#    cc core_id         country  \
# 0  US     410   United States
# 1  US     573   United States
# 2  US     253   United States
# 3  US      94   United States
# 4  GB      95  United Kingdom
#
#                                                guide  \
# 0  <a href="/where-to-study/north-america/united-...
# 1  <a href="/where-to-study/north-america/united-...
# 2  <a href="/where-to-study/north-america/united-...
# 3  <a href="/where-to-study/north-america/united-...
# 4  <a href="/where-to-study/europe/united-kingdom...
#
#                                                 logo     nid rank_display  \
# 0  <img src="https://www.topuniversities.com/site...  294850            1
# 1  <img src="https://www.topuniversities.com/site...  297282            2
# 2  <img src="https://www.topuniversities.com/site...  294270            3
# 3  <img src="https://www.topuniversities.com/site...  294562            4
# 4  <img src="https://www.topuniversities.com/site...  294561            5
#
# ...

# %%
top200_times_full.head()
# Out:
#                                       aliases        location member_level  \
# 0                        University of Oxford  United Kingdom            0
# 1                     University of Cambridge  United Kingdom            0
# 2  California Institute of Technology caltech   United States            0
# 3                         Stanford University   United States           11
# 4       Massachusetts Institute of Technology   United States            0
#
#                                TimesName     nid rank rank_order  \
# 0                   University of Oxford     468    1         10
# 1                University of Cambridge     470    2         20
# 2     California Institute of Technology  128779   =3         30
# 3                    Stanford University     467   =3         40
# 4  Massachusetts Institute of Technology     471    5         50
#
#       record_type scores_citations scores_citations_rank  \
# 0  master_account             99.1                    15
# ...

# %%
# Lets strip the university name of all junk
import re
import unidecode
def makeStringSimple(s):
    s2 = s.lower()
    s2 = unidecode.unidecode(s2)
    s2 = re.sub("[\(\[].*?[\)\]]", "", s2)
    return s2

# %%
# We score university name similarity with difflib
import difflib
matches = []
highestScores = []
for index,row in top200_times_full.iterrows():
    name = makeStringSimple(row['TimesName'])
    scores = []
    qs_nameList = list(top200_qs_full.QSname.values)
    for qsName in qs_nameList:
        scores.append(difflib.SequenceMatcher(None, name, makeStringSimple(qsName)).ratio())
        
    best = scores.index(max(scores))
    if max(scores) > 0.9:
        highestScores.append(max(scores))
        matches.append(qs_nameList[best])
    else:
        highestScores.append(0)
        matches.append(None)

# %%
pd.set_option('display.max_rows', 500)
correspondence = pd.DataFrame({'TimesName':list(top200_times_full['TimesName']),'QSname':matches, 'matchingScore': highestScores})

# %%
tempMerge = pd.merge(top200_times_full,correspondence,on='TimesName' )
top200_merged = pd.merge(tempMerge,top200_qs_full, on='QSname')

# %%
top200_merged.head()
# Out:
#                                       aliases        location member_level  \
# 0                        University of Oxford  United Kingdom            0
# 1                     University of Cambridge  United Kingdom            0
# 2  California Institute of Technology caltech   United States            0
# 3                         Stanford University   United States           11
# 4       Massachusetts Institute of Technology   United States            0
#
#                                TimesName   nid_x rank rank_order  \
# 0                   University of Oxford     468    1         10
# 1                University of Cambridge     470    2         20
# 2     California Institute of Technology  128779   =3         30
# 3                    Stanford University     467   =3         40
# 4  Massachusetts Institute of Technology     471    5         50
#
#       record_type scores_citations scores_citations_rank      ...        \
# ...

# %% [markdown]
# Extract name, rank, country and region,
# number of faculty members (international and total) and
# number of students (international and total).

# %%
df = pd.concat([top200_merged['TimesName'],top200_merged['rank'],top200_merged['rank_display'],top200_merged['country_x'], 
                top200_merged['region'], top200_merged['international_faculty_members'], top200_merged['international_students'],
                top200_merged['total_faculty_members'], top200_merged['total_students'],               
                top200_merged['stats_number_students'], top200_merged['stats_pc_intl_students'], 
                top200_merged['stats_student_staff_ratio']], axis=1)

# %%
df.head()
# Out:
#                                TimesName rank rank_display       country_x  \
# 0                   University of Oxford    1            6  United Kingdom
# 1                University of Cambridge    2            5  United Kingdom
# 2     California Institute of Technology   =3            4   United States
# 3                    Stanford University   =3            2   United States
# 4  Massachusetts Institute of Technology    5            1   United States
#
#           region  international_faculty_members  international_students  \
# 0         Europe                           2964                    7353
# 1         Europe                           2278                    6699
# 2  North America                            350                     647
# 3  North America                           2042                    3611
# 4  North America                           1679                    3717
#
#    total_faculty_members  total_students stats_number_students  \
# ...

# %%
df['rank'] = df['rank'].apply(lambda x: x[1:] if x[0]=='=' in str(x) else str(x))
df['rank_display'] = df['rank_display'].apply(lambda x: x[1:] if x[0]=='=' in str(x) else str(x))

# %%
df.corr()
# Out:
#                                international_faculty_members  \
# international_faculty_members                       1.000000
# international_students                              0.555296
# total_faculty_members                               0.627146
# total_students                                      0.286290
# stats_pc_intl_students                              0.287334
# stats_student_staff_ratio                           0.013347
#
#                                international_students  total_faculty_members  \
# international_faculty_members                0.555296               0.627146
# international_students                       1.000000               0.385782
# total_faculty_members                        0.385782               1.000000
# total_students                               0.634182               0.597199
# stats_pc_intl_students                       0.377607              -0.183786
# ...

# %% [markdown]
# When a university is strong in its international dimension, can you observe a consistency both for students and faculty members?
#
# We use the arithmetic mean of the rankings to get an aggregate. We could also have used the geometric mean, but chose not to for simplicity.

# %%
df['rank'] = df['rank'].apply(pd.to_numeric, errors='coerce')
df['rank_display'] = df['rank_display'].apply(pd.to_numeric, errors='coerce')

# %%
s = df['rank'] + df['rank_display']
pd.concat([s,df['rank'], df['rank_display']], axis=1)
new_sorting = sorted(range(len(s)), key=lambda k: s[k])
df = df.assign(new_rank = new_sorting)
indexed_df =df.set_index('new_rank')
ranked_df = indexed_df.sort_index(axis=0).TimesName
ranked_df.head(10)
# Out:
# new_rank
# 0                   California Institute of Technology
# 1                                  Stanford University
# 2                Massachusetts Institute of Technology
# 3                                 University of Oxford
# 4                              University of Cambridge
# 5                                   Harvard University
# 6                                University of Chicago
# 7                                 Princeton University
# 8                              Imperial College London
# 9    ETH Zurich – Swiss Federal Institute of Techno...
# Name: TimesName, dtype: object

# %% [markdown]
# In our approach we decided to sum together the two rankings and sort them in descending order.
