# %% [markdown]
# # Preprocessing pipeline
# Credits: https://miykael.github.io/nipype_tutorial/
#
# At the moment, this notebook has been coded to be tested on a single subject.
# Other subjects can be easily added to the "subject_list". Some small changes have to be done to the names of the images called in the notebook in order to generalize the script to all subjects.
#
# Before the preprocessing, the data format was modified using the bash function dcm2nii.

# %%
# %matplotlib inline
from os.path import join as opj
import os
import json
from nipype.interfaces.fsl import (BET, ExtractROI, FAST, FLIRT, ImageMaths,
                                   MCFLIRT, SliceTimer, Threshold)
from nipype.interfaces.spm import Smooth
from nipype.interfaces.utility import IdentityInterface, Merge
from nipype.interfaces.io import SelectFiles, DataSink, FreeSurferSource
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.pipeline.engine import Workflow, Node, MapNode
from nipype.interfaces.ants import Registration, ApplyTransforms
from nipype.interfaces.fsl import Info
from nipype.interfaces.freesurfer import FSCommand, MRIConvert, BBRegister
from nipype.interfaces.c3 import C3dAffineTool

# Import modules
from os.path import join as opj
from nipype.interfaces.spm import Normalize12
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.algorithms.misc import Gunzip
from nipype.pipeline.engine import Workflow, Node, MapNode

from nilearn import image, plotting
import numpy as np
import pylab as plt
import numpy as np
from IPython.display import SVG

# %% [markdown]
# We first define all the directories and variables that we are going to use among the notebook. The TR is the repetition time, that is the interval of time between two acquisitions.

# %%
#basedir = '/Volumes/myFatDrive/ada_project/workingdir/PPMI/'

experiment_dir = '/Volumes/myFatDrive/ada_project'

#experiment_dir = '/Users/elisabettamessina/Desktop/ADA/ada2017hw/project/ExampleFolder2'
working_dir = 'workingdir'
output_dir = 'output_folder'
input_dir_1st = 'output_folder'    # name of 1st-level output folder


# Specification to MATLAB
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('/Users/elisabettamessina/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# location of template in form of a tissue probability map to normalize to
template = '/Users/elisabettamessina/spm12/tpm/TPM.nii'

# %%
# Specify variables

# list of subject identifiers
subject_list = []
for fn in os.listdir(basedir):
    if fn[0]=='3' or fn[0]=='4':
        subject_list.append(fn)
#subject_list = ['3105']


# list of session identifiers
task_list = ['rs']

# Smoothing widths to apply
fwhm = [4, 8]

# TR of functional images
TR = 2.4 

# Isometric resample of functional images to voxel size (in mm)
iso_size = 4


#experiment_dir = '~/nipype_tutorial'          # location of experiment folder
#input_dir_1st = 'output_fMRI_example_1st'     # name of 1st-level output folder
#output_dir = 'output_fMRI_example_norm_ants'  # name of norm output folder
#working_dir = 'workingdir_fMRI_example_norm_ants'  # name of norm working directory

# %% [markdown]
# ### Defining nodes
# In the following cell we are going to define all the nodes of the preprocessing workflow, that are the separate steps that have to be performed.
# The main transformations are going to be motion correction (realignment), smoothing and co-registration, while the other nodes are functional to the main ones. In the future, the normalization node will be added to this workflow.

# %%
# ExtractROI - skip dummy scans
extract = Node(ExtractROI(t_min=4, t_size=-1),
               output_type='NIFTI',
        ~       name="extract")

# MCFLIRT - motion correction
mcflirt = Node(MCFLIRT(mean_vol=True,
                       save_plots=True,
                       output_type='NIFTI'),
               name="mcflirt")

# SliceTimer - correct for slice wise acquisition
slicetimer = Node(SliceTimer(index_dir=False,
                             interleaved=True,
                             output_type='NIFTI',
                             time_repetition=TR),
                  name="slicetimer")

# Smooth - image smoothing
smooth = Node(Smooth(), name="smooth")
smooth.iterables = ("fwhm", fwhm)

# Gunzip - unzip the structural image
gunzip_struct = Node(Gunzip(), name="gunzip_struct")

# Gunzip - unzip the contrast image
gunzip_con = MapNode(Gunzip(), name="gunzip_con",
                     iterfield=['in_file'])

# Normalize - normalizes functional and structural images to the MNI template
normalize = Node(Normalize12(jobtype='estwrite',
                             tpm=template,
                             write_voxel_sizes=[1, 1, 1]),
                 name="normalize")

# Artifact Detection - determines outliers in functional images
art = Node(ArtifactDetect(norm_threshold=2,
                          zintensity_threshold=3,
                          mask_type='spm_global',
                          parameter_source='FSL',
                          use_differences=[True, False],
                          plot_type='svg'),
           name="art")

# BET - Skullstrip anatomical Image
bet_anat = Node(BET(frac=0.5,
                    robust=True,
                    output_type='NIFTI_GZ'),
                name="bet_anat")

# FAST - Image Segmentation
segmentation = Node(FAST(output_type='NIFTI_GZ'),
                name="segmentation")

# Select WM segmentation file from segmentation output
def get_wm(files):
    return files[-1]

# Threshold - Threshold WM probability image
threshold = Node(Threshold(thresh=0.5,
                           args='-bin',
                           output_type='NIFTI_GZ'),
                name="threshold")

# FLIRT - pre-alignment of functional images to anatomical images
coreg_pre = Node(FLIRT(dof=6, output_type='NIFTI_GZ'),
                 name="coreg_pre")

# FLIRT - coregistration of functional images to anatomical images with BBR
coreg_bbr = Node(FLIRT(dof=6,
                       cost='bbr',
                       schedule=opj(os.getenv('FSLDIR'),
                                    'etc/flirtsch/bbr.sch'),
                       output_type='NIFTI_GZ'),
                 name="coreg_bbr")

# Apply coregistration warp to functional images
applywarp = Node(FLIRT(interp='spline',
                       apply_isoxfm=iso_size,
                       output_type='NIFTI'),
                 name="applywarp")

# Apply coregistration warp to mean file
applywarp_mean = Node(FLIRT(interp='spline',
                            apply_isoxfm=iso_size,
                            output_type='NIFTI_GZ'),
                 name="applywarp_mean")

# %% [markdown]
# ### Coregistration workflow
# The nypipe library provides us a smart and easy way to connect different nodes into a sequential workflow. We can first connect the nodes for the coregistration workflow, which will be then added to the main pre-processing workflow.

# %%
# Create a coregistration workflow
coregwf = Workflow(name='coregwf')
coregwf.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the coregistration workflow
coregwf.connect([(bet_anat, segmentation, [('out_file', 'in_files')]),
                 (segmentation, threshold, [(('partial_volume_files', get_wm),
                                             'in_file')]),
                 (bet_anat, coreg_pre, [('out_file', 'reference')]),
                 (threshold, coreg_bbr, [('out_file', 'wm_seg')]),
                 (coreg_pre, coreg_bbr, [('out_matrix_file', 'in_matrix_file')]),
                 (coreg_bbr, applywarp, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp, [('out_file', 'reference')]),
                 (coreg_bbr, applywarp_mean, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp_mean, [('out_file', 'reference')]),
                 ])

# %% [markdown]
# Now we need to specify where the input data can be found and where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'task_name']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('task_name', task_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
anat_file = opj('{subject_id}', 'ep2d_RESTING_STATE', 'anat', 'anat.nii')
func_file = opj('{subject_id}', 'ep2d_RESTING_STATE', 'func',
                'rest.nii')

templates = {'anat': anat_file,
             'func': func_file}
selectfiles = Node(SelectFiles(templates,
                               base_directory= experiment_dir + '/workingdir/PPMI/'),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

## Use the following DataSink output substitutions
substitutions = [('_subject_id_', ''),
                 ('_task_name_', '/task-'),
                 ('_fwhm_', 'fwhm-'),
                 ('_roi', ''),
                 ('_mcf', ''),
                 ('_st', ''),
                 ('_flirt', ''),
                 ('.nii_mean_reg', '_mean'),
                 ('.nii.par', '.par'),
                 ]
subjFolders = [('fwhm-%s/' % f, 'fwhm-%s_' % f) for f in fwhm]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ### Main preprocessing workflow

# %%
# Create a preprocessing workflow
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the preprocessing workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('task_name', 'task_name')]),
                 (selectfiles, extract, [('func', 'in_file')]),
                 (extract, mcflirt, [('roi_file', 'in_file')]),
                 (mcflirt, slicetimer, [('out_file', 'in_file')]),

                 (selectfiles, coregwf, [('anat', 'bet_anat.in_file'),
                                         ('anat', 'coreg_bbr.reference')]),
                 (mcflirt, coregwf, [('mean_img', 'coreg_pre.in_file'),
                                     ('mean_img', 'coreg_bbr.in_file'),
                                     ('mean_img', 'applywarp_mean.in_file')]),
                 (slicetimer, coregwf, [('slice_time_corrected_file', 'applywarp.in_file')]),
                 
                 (coregwf, smooth, [('applywarp.out_file', 'in_files')]),

                 (mcflirt, datasink, [('par_file', 'preproc.@par')]),
                 (smooth, datasink, [('smoothed_files', 'preproc.@smooth')]),
                 (coregwf, datasink, [('applywarp_mean.out_file', 'preproc.@mean')]),

                 (coregwf, art, [('applywarp.out_file', 'realigned_files')]),
                 (mcflirt, art, [('par_file', 'realignment_parameters')]),

                 (coregwf, datasink, [('coreg_bbr.out_matrix_file', 'preproc.@mat_file'),
                                      ('bet_anat.out_file', 'preproc.@brain')]),
                 (art, datasink, [('outlier_files', 'preproc.@outlier_files'),
                                  ('plot_files', 'preproc.@plot_files')]),
                 ])

# %%
# DEBUG MODE:
preproc.config['execution'] = {'stop_on_first_rerun': 'False',
                                   'hash_method': 'timestamp'}
from nipype import config, logging
config.enable_debug_mode()
logging.update_logging(config)

# %% [markdown]
# ### Let's run it!

# %%
preproc.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 171217-18:54:05,788 workflow DEBUG:
# 	 MultiProcPlugin starting 4 threads in pool
# 171217-18:54:05,804 workflow DEBUG:
# 	 Creating flat graph for workflow: preproc
# 171217-18:54:05,818 workflow DEBUG:
# 	 expanding workflow: preproc
# 171217-18:54:05,819 workflow DEBUG:
# 	 processing node: preproc.infosource
# 171217-18:54:05,821 workflow DEBUG:
# 	 processing node: preproc.selectfiles
# 171217-18:54:05,822 workflow DEBUG:
# 	 processing node: preproc.extract
# 171217-18:54:05,823 workflow DEBUG:
# 	 processing node: preproc.mcflirt
# 171217-18:54:05,824 workflow DEBUG:
# 	 processing node: preproc.slicetimer
# 171217-18:54:05,824 workflow DEBUG:
# 	 processing node: preproc.coregwf
# 171217-18:54:05,825 workflow DEBUG:
# 	 in: connections-> [('anat', 'bet_anat.in_file'), ('anat', 'coreg_bbr.reference')]
# 171217-18:54:05,826 workflow DEBUG:
# 	 in: ('anat', 'bet_anat.in_file')
# 171217-18:54:05,839 workflow DEBUG:
# 	 in edges: preproc.selectfiles anat coregwf.bet_anat in_file
# 171217-18:54:05,840 workflow DEBUG:
# 	 disconnect(): preproc.selectfiles->preproc.coregwf [('anat', 'bet_anat.in_file')]
# 171217-18:54:05,842 workflow DEBUG:
# 	 disconnect(): remove list [('anat', 'bet_anat.in_file')]
# 171217-18:54:05,843 workflow DEBUG:
# 	 disconnect(): removed connection ('anat', 'bet_anat.in_file')
# 171217-18:54:05,844 workflow DEBUG:
# 	 (preproc.selectfiles, coregwf.bet_anat): No edge data
# 171217-18:54:05,845 workflow DEBUG:
# 	 (preproc.selectfiles, coregwf.bet_anat): new edge data: {'connect': [('anat', 'in_file')]}
# 171217-18:54:05,845 workflow DEBUG:
# 	 in: ('anat', 'coreg_bbr.reference')
# 171217-18:54:05,856 workflow DEBUG:
# 	 in edges: preproc.selectfiles anat coregwf.coreg_bbr reference
# 171217-18:54:05,857 workflow DEBUG:
# 	 disconnect(): preproc.selectfiles->preproc.coregwf [('anat', 'coreg_bbr.reference')]
# 171217-18:54:05,858 workflow DEBUG:
# 	 disconnect(): remove list [('anat', 'coreg_bbr.reference')]
# 171217-18:54:05,859 workflow DEBUG:
# 	 disconnect(): removed connection ('anat', 'coreg_bbr.reference')
# 171217-18:54:05,860 workflow DEBUG:
# 	 (preproc.selectfiles, coregwf.coreg_bbr): No edge data
# 171217-18:54:05,861 workflow DEBUG:
# 	 (preproc.selectfiles, coregwf.coreg_bbr): new edge data: {'connect': [('anat', 'reference')]}
# 171217-18:54:05,861 workflow DEBUG:
# 	 in: connections-> [('mean_img', 'coreg_pre.in_file'), ('mean_img', 'coreg_bbr.in_file'), ('mean_img', 'applywarp_mean.in_file')]
# 171217-18:54:05,862 workflow DEBUG:
# 	 in: ('mean_img', 'coreg_pre.in_file')
# 171217-18:54:05,873 workflow DEBUG:
# 	 in edges: preproc.mcflirt mean_img coregwf.coreg_pre in_file
# 171217-18:54:05,874 workflow DEBUG:
# 	 disconnect(): preproc.mcflirt->preproc.coregwf [('mean_img', 'coreg_pre.in_file')]
# 171217-18:54:05,875 workflow DEBUG:
# 	 disconnect(): remove list [('mean_img', 'coreg_pre.in_file')]
# 171217-18:54:05,876 workflow DEBUG:
# 	 disconnect(): removed connection ('mean_img', 'coreg_pre.in_file')
# 171217-18:54:05,877 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.coreg_pre): No edge data
# 171217-18:54:05,878 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.coreg_pre): new edge data: {'connect': [('mean_img', 'in_file')]}
# 171217-18:54:05,879 workflow DEBUG:
# 	 in: ('mean_img', 'coreg_bbr.in_file')
# 171217-18:54:05,890 workflow DEBUG:
# 	 in edges: preproc.mcflirt mean_img coregwf.coreg_bbr in_file
# 171217-18:54:05,891 workflow DEBUG:
# 	 disconnect(): preproc.mcflirt->preproc.coregwf [('mean_img', 'coreg_bbr.in_file')]
# 171217-18:54:05,892 workflow DEBUG:
# 	 disconnect(): remove list [('mean_img', 'coreg_bbr.in_file')]
# 171217-18:54:05,893 workflow DEBUG:
# 	 disconnect(): removed connection ('mean_img', 'coreg_bbr.in_file')
# 171217-18:54:05,894 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.coreg_bbr): No edge data
# 171217-18:54:05,894 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.coreg_bbr): new edge data: {'connect': [('mean_img', 'in_file')]}
# 171217-18:54:05,895 workflow DEBUG:
# 	 in: ('mean_img', 'applywarp_mean.in_file')
# 171217-18:54:05,907 workflow DEBUG:
# 	 in edges: preproc.mcflirt mean_img coregwf.applywarp_mean in_file
# 171217-18:54:05,908 workflow DEBUG:
# 	 disconnect(): preproc.mcflirt->preproc.coregwf [('mean_img', 'applywarp_mean.in_file')]
# 171217-18:54:05,909 workflow DEBUG:
# 	 disconnect(): remove list [('mean_img', 'applywarp_mean.in_file')]
# 171217-18:54:05,909 workflow DEBUG:
# 	 disconnect(): removed connection ('mean_img', 'applywarp_mean.in_file')
# 171217-18:54:05,910 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.applywarp_mean): No edge data
# 171217-18:54:05,911 workflow DEBUG:
# 	 (preproc.mcflirt, coregwf.applywarp_mean): new edge data: {'connect': [('mean_img', 'in_file')]}
# 171217-18:54:05,912 workflow DEBUG:
# 	 in: connections-> [('slice_time_corrected_file', 'applywarp.in_file')]
# 171217-18:54:05,913 workflow DEBUG:
# 	 in: ('slice_time_corrected_file', 'applywarp.in_file')
# 171217-18:54:05,923 workflow DEBUG:
# 	 in edges: preproc.slicetimer slice_time_corrected_file coregwf.applywarp in_file
# 171217-18:54:05,924 workflow DEBUG:
# 	 disconnect(): preproc.slicetimer->preproc.coregwf [('slice_time_corrected_file', 'applywarp.in_file')]
# 171217-18:54:05,925 workflow DEBUG:
# 	 disconnect(): remove list [('slice_time_corrected_file', 'applywarp.in_file')]
# 171217-18:54:05,926 workflow DEBUG:
# 	 disconnect(): removed connection ('slice_time_corrected_file', 'applywarp.in_file')
# 171217-18:54:05,927 workflow DEBUG:
# 	 (preproc.slicetimer, coregwf.applywarp): No edge data
# 171217-18:54:05,928 workflow DEBUG:
# 	 (preproc.slicetimer, coregwf.applywarp): new edge data: {'connect': [('slice_time_corrected_file', 'in_file')]}
# 171217-18:54:05,929 workflow DEBUG:
# 	 out: connections-> [('applywarp.out_file', 'in_files')]
# 171217-18:54:05,930 workflow DEBUG:
# 	 out: ('applywarp.out_file', 'in_files')
# 171217-18:54:05,934 workflow DEBUG:
# 	 out edges: coregwf.applywarp out_file preproc.smooth in_files
# 171217-18:54:05,935 workflow DEBUG:
# 	 disconnect(): preproc.coregwf->preproc.smooth [('applywarp.out_file', 'in_files')]
# 171217-18:54:05,936 workflow DEBUG:
# 	 disconnect(): remove list [('applywarp.out_file', 'in_files')]
# 171217-18:54:05,937 workflow DEBUG:
# 	 disconnect(): removed connection ('applywarp.out_file', 'in_files')
# 171217-18:54:05,938 workflow DEBUG:
# 	 (coregwf.applywarp, preproc.smooth): No edge data
# 171217-18:54:05,939 workflow DEBUG:
# 	 (coregwf.applywarp, preproc.smooth): new edge data: {'connect': [('out_file', 'in_files')]}
# 171217-18:54:05,940 workflow DEBUG:
# 	 out: connections-> [('applywarp_mean.out_file', 'preproc.@mean'), ('coreg_bbr.out_matrix_file', 'preproc.@mat_file'), ('bet_anat.out_file', 'preproc.@brain')]
# 171217-18:54:05,941 workflow DEBUG:
# 	 out: ('applywarp_mean.out_file', 'preproc.@mean')
# 171217-18:54:05,946 workflow DEBUG:
# 	 out edges: coregwf.applywarp_mean out_file preproc.datasink preproc.@mean
# 171217-18:54:05,947 workflow DEBUG:
# 	 disconnect(): preproc.coregwf->preproc.datasink [('applywarp_mean.out_file', 'preproc.@mean')]
# 171217-18:54:05,948 workflow DEBUG:
# 	 disconnect(): remove list [('applywarp_mean.out_file', 'preproc.@mean')]
# 171217-18:54:05,949 workflow DEBUG:
# 	 disconnect(): removed connection ('applywarp_mean.out_file', 'preproc.@mean')
# 171217-18:54:05,950 workflow DEBUG:
# 	 (coregwf.applywarp_mean, preproc.datasink): No edge data
# 171217-18:54:05,952 workflow DEBUG:
# 	 (coregwf.applywarp_mean, preproc.datasink): new edge data: {'connect': [('out_file', 'preproc.@mean')]}
# 171217-18:54:05,953 workflow DEBUG:
# 	 out: ('coreg_bbr.out_matrix_file', 'preproc.@mat_file')
# 171217-18:54:05,957 workflow DEBUG:
# 	 out edges: coregwf.coreg_bbr out_matrix_file preproc.datasink preproc.@mat_file
# 171217-18:54:05,958 workflow DEBUG:
# 	 disconnect(): preproc.coregwf->preproc.datasink [('coreg_bbr.out_matrix_file', 'preproc.@mat_file')]
# 171217-18:54:05,959 workflow DEBUG:
# 	 disconnect(): remove list [('coreg_bbr.out_matrix_file', 'preproc.@mat_file')]
# 171217-18:54:05,960 workflow DEBUG:
# 	 disconnect(): removed connection ('coreg_bbr.out_matrix_file', 'preproc.@mat_file')
# 171217-18:54:05,961 workflow DEBUG:
# 	 (coregwf.coreg_bbr, preproc.datasink): No edge data
# 171217-18:54:05,961 workflow DEBUG:
# 	 (coregwf.coreg_bbr, preproc.datasink): new edge data: {'connect': [('out_matrix_file', 'preproc.@mat_file')]}
# 171217-18:54:05,962 workflow DEBUG:
# 	 out: ('bet_anat.out_file', 'preproc.@brain')
# 171217-18:54:05,966 workflow DEBUG:
# 	 out edges: coregwf.bet_anat out_file preproc.datasink preproc.@brain
# 171217-18:54:05,967 workflow DEBUG:
# 	 disconnect(): preproc.coregwf->preproc.datasink [('bet_anat.out_file', 'preproc.@brain')]
# 171217-18:54:05,968 workflow DEBUG:
# 	 disconnect(): remove list [('bet_anat.out_file', 'preproc.@brain')]
# 171217-18:54:05,969 workflow DEBUG:
# 	 disconnect(): removed connection ('bet_anat.out_file', 'preproc.@brain')
# 171217-18:54:05,970 workflow DEBUG:
# 	 (coregwf.bet_anat, preproc.datasink): No edge data
# 171217-18:54:05,971 workflow DEBUG:
# 	 (coregwf.bet_anat, preproc.datasink): new edge data: {'connect': [('out_file', 'preproc.@brain')]}
# 171217-18:54:05,971 workflow DEBUG:
# 	 out: connections-> [('applywarp.out_file', 'realigned_files')]
# 171217-18:54:05,972 workflow DEBUG:
# 	 out: ('applywarp.out_file', 'realigned_files')
# 171217-18:54:05,977 workflow DEBUG:
# 	 out edges: coregwf.applywarp out_file preproc.art realigned_files
# 171217-18:54:05,978 workflow DEBUG:
# 	 disconnect(): preproc.coregwf->preproc.art [('applywarp.out_file', 'realigned_files')]
# 171217-18:54:05,979 workflow DEBUG:
# 	 disconnect(): remove list [('applywarp.out_file', 'realigned_files')]
# 171217-18:54:05,980 workflow DEBUG:
# 	 disconnect(): removed connection ('applywarp.out_file', 'realigned_files')
# 171217-18:54:05,981 workflow DEBUG:
# 	 (coregwf.applywarp, preproc.art): No edge data
# 171217-18:54:05,982 workflow DEBUG:
# 	 (coregwf.applywarp, preproc.art): new edge data: {'connect': [('out_file', 'realigned_files')]}
# 171217-18:54:05,983 workflow DEBUG:
# 	 expanding workflow: preproc.coregwf
# 171217-18:54:05,984 workflow DEBUG:
# 	 processing node: coregwf.bet_anat
# 171217-18:54:05,985 workflow DEBUG:
# 	 processing node: coregwf.segmentation
# 171217-18:54:05,986 workflow DEBUG:
# 	 processing node: coregwf.threshold
# 171217-18:54:05,987 workflow DEBUG:
# 	 processing node: coregwf.coreg_pre
# 171217-18:54:05,987 workflow DEBUG:
# 	 processing node: coregwf.coreg_bbr
# 171217-18:54:05,988 workflow DEBUG:
# 	 processing node: coregwf.applywarp
# 171217-18:54:05,989 workflow DEBUG:
# 	 processing node: coregwf.applywarp_mean
# 171217-18:54:05,990 workflow DEBUG:
# 	 finished expanding workflow: preproc.coregwf
# 171217-18:54:05,991 workflow DEBUG:
# 	 processing node: preproc.smooth
# 171217-18:54:05,992 workflow DEBUG:
# 	 processing node: preproc.art
# 171217-18:54:05,992 workflow DEBUG:
# 	 processing node: preproc.datasink
# 171217-18:54:05,993 workflow DEBUG:
# 	 finished expanding workflow: preproc
# 171217-18:54:05,994 workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging']
# 171217-18:54:06,2 workflow DEBUG:
# 	 PE: expanding iterables
# 171217-18:54:06,3 workflow DEBUG:
# 	 Detected iterable nodes [preproc.smooth, preproc.infosource]
# 171217-18:54:06,4 workflow DEBUG:
# 	 Expanding the iterable node preproc.smooth...
# 171217-18:54:06,4 workflow DEBUG:
# 	 node: preproc.smooth iterables: {'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x1118f80d0>}
# 171217-18:54:06,6 workflow DEBUG:
# 	 ('subnodes:', [preproc.smooth, preproc.datasink])
# 171217-18:54:06,12 workflow DEBUG:
# 	 setting nodelevel(smooth) input fwhm = 4
# 171217-18:54:06,13 workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_4
# 171217-18:54:06,16 workflow DEBUG:
# 	 setting nodelevel(smooth) input fwhm = 8
# 171217-18:54:06,17 workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8
# 171217-18:54:06,18 workflow DEBUG:
# 	 Expanding the iterable node preproc.infosource...
# 171217-18:54:06,19 workflow DEBUG:
# 	 node: preproc.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x1118f8158>, 'task_name': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x1118f8048>}
# 171217-18:54:06,21 workflow DEBUG:
# 	 ('subnodes:', [preproc.infosource, preproc.selectfiles, preproc.extract, preproc.mcflirt, preproc.slicetimer, preproc.coregwf.applywarp, preproc.art, preproc.datasink.a0, preproc.datasink.a1, preproc.smooth.aI.a0, preproc.smooth.aI.a1, preproc.coregwf.coreg_pre, preproc.coregwf.coreg_bbr, preproc.coregwf.applywarp_mean, preproc.coregwf.bet_anat, preproc.coregwf.segmentation, preproc.coregwf.threshold])
# 171217-18:54:06,33 workflow DEBUG:
# 	 setting nodelevel(infosource) input subject_id = 3105
# 171217-18:54:06,33 workflow DEBUG:
# 	 setting nodelevel(infosource) input task_name = rs
# 171217-18:54:06,34 workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_3105_task_name_rs
# 171217-18:54:06,35 workflow DEBUG:
# 	 PE: expanding iterables ... done
# 171217-18:54:06,36 workflow DEBUG:
# 	 setting nodelevel(selectfiles) input subject_id = 3105
# 171217-18:54:06,37 workflow DEBUG:
# 	 setting nodelevel(selectfiles) input task_name = rs
# 171217-18:54:06,38 workflow DEBUG:
# 	 Removed the identity node preproc.infosource.bI.b0 from the graph.
# 171217-18:54:06,74 workflow DEBUG:
# 	 Performing depth first search
# 171217-18:54:06,89 workflow INFO:
# 	 Running in parallel.
# 171217-18:54:06,92 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-18:54:06,95 workflow INFO:
# 	 Executing: selectfiles.b0 ID: 0
# 171217-18:54:06,96 workflow DEBUG:
# 	 checking hash locally
# 171217-18:54:06,97 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:54:06,99 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:06,100 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_0x65b5e0dd084e03c2c74ce2163a9f27b0.json
# 171217-18:54:06,101 workflow DEBUG:
# 	 Hash exists False
# 171217-18:54:06,101 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:54:06,102 workflow DEBUG:
# 	 MultiProcPlugin submitting 0
# 171217-18:54:06,106 workflow INFO:
# 	 Executing node selectfiles.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles
# 171217-18:54:06,114 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:06,120 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_0x65b5e0dd084e03c2c74ce2163a9f27b0.json
# 171217-18:54:06,124 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 171217-18:54:06,127 workflow DEBUG:
# 	 Node hash: 65b5e0dd084e03c2c74ce2163a9f27b0
# 171217-18:54:06,131 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_0x65b5e0dd084e03c2c74ce2163a9f27b0_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-18:54:06,135 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles
# 171217-18:54:06,173 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_report/report.rst
# 171217-18:54:06,196 workflow DEBUG:
# 	 Executing node
# 171217-18:54:06,202 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-18:54:06,222 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.mat;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_0x65b5e0dd084e03c2c74ce2163a9f27b0_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_node.pklz
# 171217-18:54:06,226 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_report
# 171217-18:54:06,230 workflow DEBUG:
# 	 Removing files:
# 171217-18:54:06,240 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/result_selectfiles.pklz
# 171217-18:54:06,244 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/_report/report.rst
# 171217-18:54:06,260 workflow DEBUG:
# 	 Finished running selectfiles.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles
#
# 171217-18:54:06,265 workflow INFO:
# 	 [Job finished] jobname: selectfiles.b0 jobid: 0
# 171217-18:54:06,267 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-18:54:06,269 workflow INFO:
# 	 Executing: extract.b0 ID: 1
# 171217-18:54:06,270 workflow DEBUG:
# 	 checking hash locally
# 171217-18:54:06,270 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:54:06,271 workflow DEBUG:
# 	 input: in_file
# 171217-18:54:06,272 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/result_selectfiles.pklz
# 171217-18:54:06,274 workflow DEBUG:
# 	 output: func
# 171217-18:54:06,275 workflow DEBUG:
# 	 setting nodelevel(extract) input in_file = /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii
# 171217-18:54:06,277 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:06,277 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_0xc849633a51873de90cc4794e5295990b.json
# 171217-18:54:06,278 workflow DEBUG:
# 	 Hash exists False
# 171217-18:54:06,279 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:54:06,280 workflow DEBUG:
# 	 MultiProcPlugin submitting 1
# 171217-18:54:06,281 workflow INFO:
# 	 Executing: bet_anat.b0 ID: 4
# 171217-18:54:06,283 workflow DEBUG:
# 	 checking hash locally
# 171217-18:54:06,284 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:54:06,284 workflow DEBUG:
# 	 input: in_file
# 171217-18:54:06,285 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/selectfiles/result_selectfiles.pklz
# 171217-18:54:06,287 workflow DEBUG:
# 	 output: anat
# 171217-18:54:06,284 workflow INFO:
# 	 Executing node extract.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract171217-18:54:06,288 workflow DEBUG:
# 	 setting nodelevel(bet_anat) input in_file = /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii
#
# 171217-18:54:06,290 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:06,291 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_0xea9949265261eea4e903d65608036fc5.json
# 171217-18:54:06,292 workflow DEBUG:
# 	 Hash exists False
# 171217-18:54:06,293 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:54:06,294 workflow DEBUG:
# 	 MultiProcPlugin submitting 4
# 171217-18:54:06,293 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:06,300 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_0xc849633a51873de90cc4794e5295990b.json
# 171217-18:54:06,300 workflow INFO:
# 	 Executing node bet_anat.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat171217-18:54:06,304 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
#
# 171217-18:54:06,308 workflow DEBUG:
# 	 Node hash: c849633a51873de90cc4794e5295990b171217-18:54:06,307 workflow DEBUG:
# 	 Found hashfiles: []
#
# 171217-18:54:06,311 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_0xc849633a51873de90cc4794e5295990b_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution171217-18:54:06,313 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_0xea9949265261eea4e903d65608036fc5.json
#
# 171217-18:54:06,315 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract
# 171217-18:54:06,317 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-18:54:06,321 workflow DEBUG:
# 	 Node hash: ea9949265261eea4e903d65608036fc5
# 171217-18:54:06,326 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_0xea9949265261eea4e903d65608036fc5_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-18:54:06,330 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat
# 171217-18:54:06,348 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_report/report.rst
# 171217-18:54:06,440 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_report/report.rst
# 171217-18:54:06,450 workflow DEBUG:
# 	 Executing node
# 171217-18:54:06,454 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-18:54:06,458 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii
# 171217-18:54:06,462 interface DEBUG:
# 	 roi_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz
# 171217-18:54:06,468 interface DEBUG:
# 	 t_min_4
# 171217-18:54:06,473 interface DEBUG:
# 	 t_size_-1
# 171217-18:54:06,493 workflow INFO:
# 	 Running: fslroi /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz 4 -1171217-18:54:06,494 workflow DEBUG:
# 	 Executing node
#
# 171217-18:54:06,498 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]171217-18:54:06,498 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii
#
# 171217-18:54:06,502 interface DEBUG:
# 	 roi_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz171217-18:54:06,503 interface DEBUG:
# 	 frac_0.5
#
# 171217-18:54:06,506 interface DEBUG:
# 	 t_min_4171217-18:54:06,507 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii
#
# 171217-18:54:06,511 interface DEBUG:
# 	 t_size_-1171217-18:54:06,512 interface DEBUG:
# 	 out_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz
#
# 171217-18:54:06,514 interface DEBUG:
# 	 {'DISPLAY': ':1'}171217-18:54:06,515 interface DEBUG:
# 	 robust_True
#
# 171217-18:54:06,536 workflow INFO:
# 	 Running: bet /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz -f 0.50 -R
# 171217-18:54:06,542 interface DEBUG:
# 	 frac_0.5
# 171217-18:54:06,546 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii
# 171217-18:54:06,550 interface DEBUG:
# 	 out_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz
# 171217-18:54:06,553 interface DEBUG:
# 	 robust_True
# 171217-18:54:06,556 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-18:54:08,298 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:08,299 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:10,304 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:10,305 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:12,310 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:12,311 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:14,314 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:14,315 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:16,318 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:16,319 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:18,322 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:18,323 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:19,645 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.nii;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/func/rest.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_0xc849633a51873de90cc4794e5295990b_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/command.txt;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_node.pklz
# 171217-18:54:19,649 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_report
# 171217-18:54:19,653 workflow DEBUG:
# 	 Removing files:
# 171217-18:54:19,663 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/result_extract.pklz
# 171217-18:54:19,667 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/_report/report.rst
# 171217-18:54:19,673 workflow DEBUG:
# 	 Finished running extract.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract
#
# 171217-18:54:19,677 workflow INFO:
# 	 [Job finished] jobname: extract.b0 jobid: 1
# 171217-18:54:19,679 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-18:54:19,681 workflow INFO:
# 	 Executing: mcflirt.b0 ID: 2
# 171217-18:54:19,682 workflow DEBUG:
# 	 checking hash locally
# 171217-18:54:19,683 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:54:19,683 workflow DEBUG:
# 	 input: in_file
# 171217-18:54:19,684 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/result_extract.pklz
# 171217-18:54:19,686 workflow DEBUG:
# 	 output: roi_file
# 171217-18:54:19,687 workflow DEBUG:
# 	 setting nodelevel(mcflirt) input in_file = /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz
# 171217-18:54:19,689 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:19,690 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_0x5e7d4d917533e29dd814c3c3b0fd8c68.json
# 171217-18:54:19,691 workflow DEBUG:
# 	 Hash exists False
# 171217-18:54:19,692 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:54:19,693 workflow DEBUG:
# 	 MultiProcPlugin submitting 2
# 171217-18:54:19,697 workflow INFO:
# 	 Executing node mcflirt.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt
# 171217-18:54:19,705 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:19,711 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_0x5e7d4d917533e29dd814c3c3b0fd8c68.json
# 171217-18:54:19,716 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-18:54:19,720 workflow DEBUG:
# 	 Node hash: 5e7d4d917533e29dd814c3c3b0fd8c68
# 171217-18:54:19,723 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_0x5e7d4d917533e29dd814c3c3b0fd8c68_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-18:54:19,727 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt
# 171217-18:54:19,746 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_report/report.rst
# 171217-18:54:19,811 workflow DEBUG:
# 	 Executing node
# 171217-18:54:19,821 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-18:54:19,833 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz
# 171217-18:54:19,843 interface DEBUG:
# 	 mean_vol_True
# 171217-18:54:19,854 interface DEBUG:
# 	 out_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii
# 171217-18:54:19,865 interface DEBUG:
# 	 save_plots_True
# 171217-18:54:19,886 workflow INFO:
# 	 Running: mcflirt -in /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz -meanvol -out /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii -plots
# 171217-18:54:19,892 interface DEBUG:
# 	 in_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz
# 171217-18:54:19,895 interface DEBUG:
# 	 mean_vol_True
# 171217-18:54:19,900 interface DEBUG:
# 	 out_file_/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii
# 171217-18:54:19,903 interface DEBUG:
# 	 save_plots_True
# 171217-18:54:19,907 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-18:54:21,695 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:21,696 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:23,703 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:23,704 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:25,711 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:25,713 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:27,720 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:27,722 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:29,724 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:29,725 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:31,730 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:31,732 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:33,736 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:33,737 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:35,744 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:35,745 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:37,753 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:37,754 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:39,757 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:39,759 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:41,763 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:41,764 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:43,767 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:43,769 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:45,772 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:45,773 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:46,246 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.nii;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/anat.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_0xea9949265261eea4e903d65608036fc5_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/command.txt;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_node.pklz
# 171217-18:54:46,251 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_report
# 171217-18:54:46,255 workflow DEBUG:
# 	 Removing files:
# 171217-18:54:46,274 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/result_bet_anat.pklz
# 171217-18:54:46,286 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/_report/report.rst
# 171217-18:54:46,300 workflow DEBUG:
# 	 Finished running bet_anat.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat
#
# 171217-18:54:46,314 workflow INFO:
# 	 [Job finished] jobname: bet_anat.b0 jobid: 4
# 171217-18:54:46,317 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-18:54:46,320 workflow INFO:
# 	 Executing: segmentation.b0 ID: 5
# 171217-18:54:46,321 workflow DEBUG:
# 	 checking hash locally
# 171217-18:54:46,322 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:54:46,324 workflow DEBUG:
# 	 input: in_files
# 171217-18:54:46,325 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/result_bet_anat.pklz
# 171217-18:54:46,327 workflow DEBUG:
# 	 output: out_file
# 171217-18:54:46,328 workflow DEBUG:
# 	 setting nodelevel(segmentation) input in_files = /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz
# 171217-18:54:46,330 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:46,331 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/_0x00853cb5c9c801ea4cb27b7e24ce535f.json
# 171217-18:54:46,333 workflow DEBUG:
# 	 Hash exists False
# 171217-18:54:46,334 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:54:46,335 workflow DEBUG:
# 	 MultiProcPlugin submitting 5
# 171217-18:54:46,340 workflow INFO:
# 	 Executing node segmentation.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation
# 171217-18:54:46,348 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:54:46,357 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/_0x00853cb5c9c801ea4cb27b7e24ce535f.json
# 171217-18:54:46,366 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-18:54:46,375 workflow DEBUG:
# 	 Node hash: 00853cb5c9c801ea4cb27b7e24ce535f
# 171217-18:54:46,384 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/_0x00853cb5c9c801ea4cb27b7e24ce535f_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-18:54:46,393 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation
# 171217-18:54:46,418 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/_report/report.rst
# 171217-18:54:46,448 workflow DEBUG:
# 	 Executing node
# 171217-18:54:46,451 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-18:54:46,472 interface DEBUG:
# 	 in_files_['/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/anat_brain.nii.gz']
# 171217-18:54:46,483 workflow INFO:
# 	 Running: fast -S 1 /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/anat_brain.nii.gz
# 171217-18:54:46,489 interface DEBUG:
# 	 in_files_['/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/segmentation/anat_brain.nii.gz']
# 171217-18:54:46,493 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-18:54:48,342 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:48,343 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:50,349 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:50,350 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:52,353 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:52,355 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:54,358 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:54,359 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:56,363 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:56,364 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:54:58,367 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:54:58,368 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:00,375 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:00,376 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:02,380 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:02,381 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:04,385 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:04,386 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:06,392 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:06,393 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:08,401 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:08,402 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:10,407 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:10,408 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:12,416 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:12,417 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:14,420 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:14,422 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:16,427 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:16,428 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:18,435 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:18,436 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:20,443 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:20,444 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:22,451 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:22,452 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:24,457 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:24,458 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:26,463 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:26,464 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:28,468 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:28,470 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:30,478 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:30,479 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:32,484 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:32,486 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:34,489 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:34,491 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:36,499 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:36,500 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:38,505 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:38,506 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:40,509 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:40,510 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:42,515 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:42,516 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:44,520 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:44,521 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:46,524 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:46,526 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:48,533 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:48,535 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:50,542 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-18:55:50,544 workflow DEBUG:
# 	 Number of pending tasks: 2
# 171217-18:55:51,981 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii_mean_reg.nii;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii_mean_reg.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii.par;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/extract/rest_roi.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_0x5e7d4d917533e29dd814c3c3b0fd8c68_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/command.txt;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_node.pklz
# 171217-18:55:51,986 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_report
# 171217-18:55:51,989 workflow DEBUG:
# 	 Removing files:
# 171217-18:55:51,999 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/result_mcflirt.pklz
# 171217-18:55:52,4 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/_report/report.rst
# 171217-18:55:52,10 workflow DEBUG:
# 	 Finished running mcflirt.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt
#
# 171217-18:55:52,16 workflow INFO:
# 	 [Job finished] jobname: mcflirt.b0 jobid: 2
# 171217-18:55:52,18 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-18:55:52,20 workflow INFO:
# 	 Executing: slicetimer.b0 ID: 3
# 171217-18:55:52,21 workflow DEBUG:
# 	 checking hash locally
# 171217-18:55:52,22 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:55:52,23 workflow DEBUG:
# 	 input: in_file
# 171217-18:55:52,25 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/result_mcflirt.pklz
# 171217-18:55:52,27 workflow DEBUG:
# 	 output: out_file
# 171217-18:55:52,28 workflow DEBUG:
# 	 setting nodelevel(slicetimer) input in_file = /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii
# 171217-18:55:52,30 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:55:52,31 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/slicetimer/_0x1932dfce9f9d452f69420d5979f804ec.json
# 171217-18:55:52,31 workflow DEBUG:
# 	 Hash exists False
# 171217-18:55:52,32 workflow DEBUG:
# 	 Finished checking hash
# 171217-18:55:52,33 workflow DEBUG:
# 	 MultiProcPlugin submitting 3
# 171217-18:55:52,35 workflow INFO:
# 	 Executing: coreg_pre.b0 ID: 7
# 171217-18:55:52,36 workflow DEBUG:
# 	 checking hash locally
# 171217-18:55:52,37 workflow DEBUG:
# 	 Setting node inputs
# 171217-18:55:52,36 workflow INFO:
# 	 Executing node slicetimer.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/slicetimer171217-18:55:52,38 workflow DEBUG:
# 	 input: in_file
#
# 171217-18:55:52,39 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/result_mcflirt.pklz
# 171217-18:55:52,42 workflow DEBUG:
# 	 output: mean_img
# 171217-18:55:52,41 workflow DEBUG:
# 	 Found hashfiles: []171217-18:55:52,43 workflow DEBUG:
# 	 setting nodelevel(coreg_pre) input in_file = /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii_mean_reg.nii
#
# 171217-18:55:52,44 workflow DEBUG:
# 	 input: reference
# 171217-18:55:52,45 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/result_bet_anat.pklz
# 171217-18:55:52,44 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/slicetimer/_0x1932dfce9f9d452f69420d5979f804ec.json171217-18:55:52,47 workflow DEBUG:
# 	 output: out_file
#
# 171217-18:55:52,48 workflow DEBUG:
# 	 setting nodelevel(coreg_pre) input reference = /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz
# 171217-18:55:52,48 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-18:55:52,51 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-18:55:52,52 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_pre/_0xcae34d38b48ff3000be9f1eb0205452c.json
# 171217-18:55:52,52 workflow DEBUG:
# 	 Node hash: 1932dfce9f9d452f69420d5979f804ec171217-18:55:52,53 workflow DEBUG:
# 	 Hash exists False
# 171217-18:55:52,55 workflow DEBUG:
# 	 Finished checking hash
#
# 171217-18:55:52,56 workflow DEBUG:
# 	 MultiProcPlugin submitting 7
# 171217-18:55:52,57 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/slicetimer/_0x1932dfce9f9d452f69420d5979f804ec_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-18:55:52,60 workflow INFO:
# ...
# 171217-19:10:44,712 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/art/art.rest_roi_mcf_st_flirt_outliers.txt /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/art.rest_outliers.txt
# 171217-19:10:44,720 interface DEBUG:
# 	 key: preproc.@plot_files files: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/art/plot.rest_roi_mcf_st_flirt.svg
# 171217-19:10:44,731 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/plot.rest_roi_mcf_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/plot.rest_roi_mcf_st_flirt.svg using '_subject_id_' -> ''
# 171217-19:10:44,738 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/plot.rest_roi_mcf_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_roi_mcf_st_flirt.svg using '_task_name_' -> '/task-'
# 171217-19:10:44,747 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_roi_mcf_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_mcf_st_flirt.svg using '_roi' -> ''
# 171217-19:10:44,756 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_mcf_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_st_flirt.svg using '_mcf' -> ''
# 171217-19:10:44,763 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_flirt.svg using '_st' -> ''
# 171217-19:10:44,773 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest.svg using '_flirt' -> ''
# 171217-19:10:44,780 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/plot.rest_roi_mcf_st_flirt.svg -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest.svg
# 171217-19:10:44,788 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/art/plot.rest_roi_mcf_st_flirt.svg /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest.svg
# 171217-19:10:44,796 interface DEBUG:
# 	 key: preproc.@smooth files: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/smooth/srest_roi_mcf_st_flirt.nii
# 171217-19:10:44,813 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/_fwhm_8/srest_roi_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/_fwhm_8/srest_roi_mcf_st_flirt.nii using '_subject_id_' -> ''
# 171217-19:10:44,821 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/_fwhm_8/srest_roi_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/_fwhm_8/srest_roi_mcf_st_flirt.nii using '_task_name_' -> '/task-'
# 171217-19:10:44,829 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/_fwhm_8/srest_roi_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_roi_mcf_st_flirt.nii using '_fwhm_' -> 'fwhm-'
# 171217-19:10:44,836 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_roi_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_mcf_st_flirt.nii using '_roi' -> ''
# 171217-19:10:44,843 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_st_flirt.nii using '_mcf' -> ''
# 171217-19:10:44,851 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_flirt.nii using '_st' -> ''
# 171217-19:10:44,861 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest.nii using '_flirt' -> ''
# 171217-19:10:44,870 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8/srest.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8_srest.nii using 'fwhm-8/' -> 'fwhm-8_'
# 171217-19:10:44,877 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/_fwhm_8/srest_roi_mcf_st_flirt.nii -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8_srest.nii
# 171217-19:10:44,884 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/smooth/srest_roi_mcf_st_flirt.nii /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8_srest.nii
# 171217-19:10:46,472 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:46,473 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:48,477 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:48,478 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:50,481 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:50,483 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:52,299 interface DEBUG:
# 	 key: preproc.@mat_file files: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.mat
# 171217-19:10:52,308 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.mat using '_subject_id_' -> ''
# 171217-19:10:52,315 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_roi_mcf.nii_mean_reg_flirt.mat using '_task_name_' -> '/task-'
# 171217-19:10:52,321 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_roi_mcf.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mcf.nii_mean_reg_flirt.mat using '_roi' -> ''
# 171217-19:10:52,327 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mcf.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg_flirt.mat using '_mcf' -> ''
# 171217-19:10:52,334 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg.mat using '_flirt' -> ''
# 171217-19:10:52,339 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.mat using '.nii_mean_reg' -> '_mean'
# 171217-19:10:52,345 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.mat -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.mat
# 171217-19:10:52,352 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.mat /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.mat
# 171217-19:10:52,382 interface DEBUG:
# 	 key: preproc.@mean files: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/applywarp_mean/rest_roi_mcf.nii_mean_reg_flirt.nii.gz
# 171217-19:10:52,388 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz using '_subject_id_' -> ''
# 171217-19:10:52,394 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz using '_task_name_' -> '/task-'
# 171217-19:10:52,403 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mcf.nii_mean_reg_flirt.nii.gz using '_roi' -> ''
# 171217-19:10:52,410 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mcf.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg_flirt.nii.gz using '_mcf' -> ''
# 171217-19:10:52,418 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg.nii.gz using '_flirt' -> ''
# 171217-19:10:52,425 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.nii_mean_reg.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz using '.nii_mean_reg' -> '_mean'
# 171217-19:10:52,432 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/rest_roi_mcf.nii_mean_reg_flirt.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz
# 171217-19:10:52,438 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/applywarp_mean/rest_roi_mcf.nii_mean_reg_flirt.nii.gz /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz
# 171217-19:10:52,449 interface DEBUG:
# 	 key: preproc.@brain files: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz
# 171217-19:10:52,457 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/anat_brain.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/anat_brain.nii.gz using '_subject_id_' -> ''
# 171217-19:10:52,464 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105_task_name_rs/anat_brain.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/anat_brain.nii.gz using '_task_name_' -> '/task-'
# 171217-19:10:52,472 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/preproc/_subject_id_3105_task_name_rs/anat_brain.nii.gz -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/anat_brain.nii.gz
# 171217-19:10:52,479 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/anat_brain.nii.gz
# 171217-19:10:52,487 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:52,488 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:52,526 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest.par;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/art.rest_outliers.txt;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/plot.rest.svg;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8_srest.nii;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/fwhm-8_srest.mat;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.hdr;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.img;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.mat;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.mat;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/anat_brain.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/bet_anat/anat_brain.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.hdr;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.img;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.nii;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/coreg_bbr/rest_roi_mcf.nii_mean_reg_flirt.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/coregwf/_subject_id_3105_task_name_rs/applywarp_mean/rest_roi_mcf.nii_mean_reg_flirt.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/art/art.rest_roi_mcf_st_flirt_outliers.txt;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/mcflirt/rest_roi_mcf.nii.par;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/art/plot.rest_roi_mcf_st_flirt.svg;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/smooth/srest_roi_mcf_st_flirt.nii;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/smooth/srest_roi_mcf_st_flirt.mat;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/_0x73e050b97d10e160b091624735855c00_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/_node.pklz
# 171217-19:10:52,534 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/_report
# 171217-19:10:52,540 workflow DEBUG:
# 	 Removing files:
# 171217-19:10:52,563 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/result_datasink.pklz
# 171217-19:10:52,571 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink/_report/report.rst
# 171217-19:10:52,589 workflow DEBUG:
# 	 Finished running datasink.a1.b0 in dir: /Volumes/myFatDrive/ada_project/workingdir/preproc/_subject_id_3105_task_name_rs/_fwhm_8/datasink
#
# 171217-19:10:52,600 workflow INFO:
# 	 [Job finished] jobname: datasink.a1.b0 jobid: 15
# 171217-19:10:52,603 workflow DEBUG:
# 	 Number of pending tasks: 0

# %% [markdown]
# ### Normalization workflow

# %%
 # Gunzip - unzip the structural image
gunzip_struct = Node(Gunzip(), name="gunzip_struct")

# Gunzip - unzip the contrast image
gunzip_con = MapNode(Gunzip(), name="gunzip_con",
                     iterfield=['in_file'])
# Out:
# 171217-19:10:52,720 workflow DEBUG:
# 	 adding multipath trait: in_file

# %%
# Normalize - normalizes functional and structural images to the MNI template
normalize = Node(Normalize12(jobtype='estwrite',
                             tpm=template,
                             write_voxel_sizes=[1, 1, 1]),
                 name="normalize")

# %%
# Specify Normalization-Workflow & Connect Nodes
normflow = Workflow(name='normflow')
normflow.base_dir = opj(experiment_dir, working_dir)

# Connect up ANTS normalization components
normflow.connect([(gunzip_struct, normalize, [('out_file', 'image_to_align')]),
                  (gunzip_con, normalize, [('out_file', 'apply_to_files')]),
                  ])
# Out:
# 171217-19:10:52,762 workflow DEBUG:
# 	 (normflow.gunzip_struct, normflow.normalize): No edge data
# 171217-19:10:52,764 workflow DEBUG:
# 	 (normflow.gunzip_struct, normflow.normalize): new edge data: {'connect': [('out_file', 'image_to_align')]}
# 171217-19:10:52,766 workflow DEBUG:
# 	 (normflow.gunzip_con, normflow.normalize): No edge data
# 171217-19:10:52,767 workflow DEBUG:
# 	 (normflow.gunzip_con, normflow.normalize): new edge data: {'connect': [('out_file', 'apply_to_files')]}

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
anat_file = opj(working_dir, 'PPMI', '{subject_id}', 'ep2d_RESTING_STATE', 'anat', 'zipped', 'anat.nii.gz')
con_file = opj(output_dir, 'preproc', '{subject_id}', 'task-rs',
                        'rest_mean.nii.gz')


templates = {'anat': anat_file,
             'con': con_file,
             }
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', '')]
datasink.inputs.substitutions = substitutions

# Connect SelectFiles and DataSink to the workflow
normflow.connect([(infosource, selectfiles, [('subject_id', 'subject_id')]),
                  (selectfiles, gunzip_struct, [('anat', 'in_file')]),
                  (selectfiles, gunzip_con, [('con', 'in_file')]),
                  (normalize, datasink, [('normalized_files',
                                          'normalized.@files'),
                                         ('normalized_image',
                                          'normalized.@image'),
                                         ('deformation_field',
                                          'normalized.@field'),
                                         ]),
                  ])
# Out:
# 171217-19:10:52,809 workflow DEBUG:
# 	 (normflow.infosource, normflow.selectfiles): No edge data
# 171217-19:10:52,810 workflow DEBUG:
# 	 (normflow.infosource, normflow.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 171217-19:10:52,812 workflow DEBUG:
# 	 (normflow.selectfiles, normflow.gunzip_struct): No edge data
# 171217-19:10:52,813 workflow DEBUG:
# 	 (normflow.selectfiles, normflow.gunzip_struct): new edge data: {'connect': [('anat', 'in_file')]}
# 171217-19:10:52,814 workflow DEBUG:
# 	 (normflow.selectfiles, normflow.gunzip_con): No edge data
# 171217-19:10:52,816 workflow DEBUG:
# 	 (normflow.selectfiles, normflow.gunzip_con): new edge data: {'connect': [('con', 'in_file')]}
# 171217-19:10:52,817 workflow DEBUG:
# 	 (normflow.normalize, normflow.datasink): No edge data
# 171217-19:10:52,818 workflow DEBUG:
# 	 (normflow.normalize, normflow.datasink): new edge data: {'connect': [('normalized_files', 'normalized.@files'), ('normalized_image', 'normalized.@image'), ('deformation_field', 'normalized.@field')]}

# %%
# DEBUG MODE:
normflow.config['execution'] = {'stop_on_first_rerun': 'False',
                                   'hash_method': 'timestamp'}
from nipype import config, logging
config.enable_debug_mode()
logging.update_logging(config)

# %%
normflow.run('MultiProc', plugin_args={'n_procs': 8})
# Out:
# 171217-19:10:52,872 workflow DEBUG:
# 	 MultiProcPlugin starting 8 threads in pool
# 171217-19:10:52,917 workflow DEBUG:
# 	 Creating flat graph for workflow: normflow
# 171217-19:10:52,931 workflow DEBUG:
# 	 expanding workflow: normflow
# 171217-19:10:52,933 workflow DEBUG:
# 	 processing node: normflow.infosource
# 171217-19:10:52,934 workflow DEBUG:
# 	 processing node: normflow.selectfiles
# 171217-19:10:52,936 workflow DEBUG:
# 	 processing node: normflow.gunzip_con
# 171217-19:10:52,949 workflow DEBUG:
# 	 processing node: normflow.gunzip_struct
# 171217-19:10:52,950 workflow DEBUG:
# 	 processing node: normflow.normalize
# 171217-19:10:52,951 workflow DEBUG:
# 	 processing node: normflow.datasink
# 171217-19:10:52,953 workflow DEBUG:
# 	 finished expanding workflow: normflow
# 171217-19:10:52,954 workflow INFO:
# 	 Workflow normflow settings: ['check', 'execution', 'logging']
# 171217-19:10:52,962 workflow DEBUG:
# 	 PE: expanding iterables
# 171217-19:10:52,965 workflow DEBUG:
# 	 Detected iterable nodes [normflow.infosource]
# 171217-19:10:52,967 workflow DEBUG:
# 	 Expanding the iterable node normflow.infosource...
# 171217-19:10:52,968 workflow DEBUG:
# 	 node: normflow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x111916e18>}
# 171217-19:10:52,971 workflow DEBUG:
# 	 ('subnodes:', [normflow.infosource, normflow.selectfiles, normflow.gunzip_struct, normflow.normalize, normflow.datasink, normflow.gunzip_con])
# 171217-19:10:52,982 workflow DEBUG:
# 	 setting nodelevel(infosource) input subject_id = 3105
# 171217-19:10:52,985 workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_3105
# 171217-19:10:52,986 workflow DEBUG:
# 	 PE: expanding iterables ... done
# 171217-19:10:52,988 workflow DEBUG:
# 	 setting nodelevel(selectfiles) input subject_id = 3105
# 171217-19:10:52,989 workflow DEBUG:
# 	 Removed the identity node normflow.infosource.aI.a0 from the graph.
# 171217-19:10:53,38 workflow DEBUG:
# 	 Performing depth first search
# 171217-19:10:53,66 workflow INFO:
# 	 Running in parallel.
# 171217-19:10:53,72 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-19:10:53,76 workflow INFO:
# 	 Executing: selectfiles.a0 ID: 0
# 171217-19:10:53,78 workflow DEBUG:
# 	 checking hash locally
# 171217-19:10:53,80 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:10:53,83 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:53,84 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_0x345b8bffd85af6d71b257e20ad95c039.json
# 171217-19:10:53,86 workflow DEBUG:
# 	 Hash exists False
# 171217-19:10:53,87 workflow DEBUG:
# 	 Finished checking hash
# 171217-19:10:53,89 workflow DEBUG:
# 	 MultiProcPlugin submitting 0
# 171217-19:10:53,95 workflow INFO:
# 	 Executing node selectfiles.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles
# 171217-19:10:53,108 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:53,115 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_0x345b8bffd85af6d71b257e20ad95c039.json
# 171217-19:10:53,121 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 171217-19:10:53,127 workflow DEBUG:
# 	 Node hash: 345b8bffd85af6d71b257e20ad95c039
# 171217-19:10:53,133 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_0x345b8bffd85af6d71b257e20ad95c039_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-19:10:53,140 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles
# 171217-19:10:53,197 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_report/report.rst
# 171217-19:10:53,238 workflow DEBUG:
# 	 Executing node
# 171217-19:10:53,247 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-19:10:53,264 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/zipped/anat.nii.gz;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_0x345b8bffd85af6d71b257e20ad95c039_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_node.pklz
# 171217-19:10:53,270 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_report
# 171217-19:10:53,279 workflow DEBUG:
# 	 Removing files:
# 171217-19:10:53,297 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/result_selectfiles.pklz
# 171217-19:10:53,304 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/_report/report.rst
# 171217-19:10:53,312 workflow DEBUG:
# 	 Finished running selectfiles.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles
#
# 171217-19:10:53,320 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a0 jobid: 0
# 171217-19:10:53,324 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-19:10:53,327 workflow INFO:
# 	 Executing: gunzip_struct.a0 ID: 1
# 171217-19:10:53,329 workflow DEBUG:
# 	 checking hash locally
# 171217-19:10:53,330 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:10:53,331 workflow DEBUG:
# 	 input: in_file
# 171217-19:10:53,332 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/result_selectfiles.pklz
# 171217-19:10:53,335 workflow DEBUG:
# 	 output: anat
# 171217-19:10:53,336 workflow DEBUG:
# 	 setting nodelevel(gunzip_struct) input in_file = /Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/zipped/anat.nii.gz
# 171217-19:10:53,338 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:53,339 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_0xdef88a2df65a317b3c6d10f50c453093.json
# 171217-19:10:53,340 workflow DEBUG:
# 	 Hash exists False
# 171217-19:10:53,341 workflow DEBUG:
# 	 Finished checking hash
# 171217-19:10:53,343 workflow DEBUG:
# 	 MultiProcPlugin submitting 1
# 171217-19:10:53,345 workflow INFO:
# 	 Executing: gunzip_con.a0 ID: 2
# 171217-19:10:53,347 workflow DEBUG:
# 	 adding multipath trait: in_file
# 171217-19:10:53,349 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:10:53,350 workflow DEBUG:
# 	 input: in_file
# 171217-19:10:53,351 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/selectfiles/result_selectfiles.pklz
# 171217-19:10:53,354 workflow DEBUG:
# 	 output: con
# 171217-19:10:53,348 workflow INFO:
# 	 Executing node gunzip_struct.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct171217-19:10:53,355 workflow DEBUG:
# 	 setting nodelevel(normflow.gunzip_con.a0) input in_file = /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz
# 171217-19:10:53,357 workflow DEBUG:
# 	 setting mapnode(normflow.gunzip_con.a0) input: in_file -> /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz
#
# 171217-19:10:53,358 workflow DEBUG:
# 	 checking hash locally
# 171217-19:10:53,360 workflow DEBUG:
# 	 setting hashinput in_file-> ['/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz']
# 171217-19:10:53,362 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:53,361 workflow DEBUG:
# 	 Found hashfiles: []171217-19:10:53,363 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/_0xb18b4645cab3c548d6ccfa1c3a8e5b89.json
# 171217-19:10:53,365 workflow DEBUG:
# 	 Hash exists False
#
# 171217-19:10:53,367 workflow DEBUG:
# 	 Finished checking hash
# 171217-19:10:53,368 workflow DEBUG:
# 	 MultiProcPlugin submitting 2
# 171217-19:10:53,367 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_0xdef88a2df65a317b3c6d10f50c453093.json
# 171217-19:10:53,374 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-19:10:53,374 workflow INFO:
# 	 Executing node gunzip_con.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con171217-19:10:53,379 workflow DEBUG:
# 	 Node hash: def88a2df65a317b3c6d10f50c453093
#
# 171217-19:10:53,384 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_0xdef88a2df65a317b3c6d10f50c453093_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution171217-19:10:53,384 workflow DEBUG:
# 	 setting hashinput in_file-> ['/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz']
#
# 171217-19:10:53,390 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct171217-19:10:53,391 workflow DEBUG:
# 	 Found hashfiles: []
#
# 171217-19:10:53,398 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/_0xb18b4645cab3c548d6ccfa1c3a8e5b89.json
# 171217-19:10:53,405 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-19:10:53,411 workflow DEBUG:
# 	 Node hash: b18b4645cab3c548d6ccfa1c3a8e5b89
# 171217-19:10:53,417 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/_0xb18b4645cab3c548d6ccfa1c3a8e5b89_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-19:10:53,423 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con
# 171217-19:10:53,440 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_report/report.rst
# 171217-19:10:53,478 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/_report/report.rst
# 171217-19:10:53,509 workflow DEBUG:
# 	 Executing node
# 171217-19:10:53,516 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-19:10:53,542 workflow DEBUG:
# 	 setting input 0 in_file /Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz
# 171217-19:10:53,548 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:10:53,556 workflow INFO:
# 	 Executing node _gunzip_con0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0
# 171217-19:10:53,564 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:53,571 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_0xf2917dbbd35ab6d24f5adef5e4796810.json
# 171217-19:10:53,578 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-19:10:53,586 workflow DEBUG:
# 	 Node hash: f2917dbbd35ab6d24f5adef5e4796810
# 171217-19:10:53,591 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_0xf2917dbbd35ab6d24f5adef5e4796810_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-19:10:53,597 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0
# 171217-19:10:53,722 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_report/report.rst
# 171217-19:10:53,799 workflow DEBUG:
# 	 Executing node
# 171217-19:10:53,806 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-19:10:53,848 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/rest_mean.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/rest_mean.mat;/Volumes/myFatDrive/ada_project/output_folder/preproc/3105/task-rs/rest_mean.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_0xf2917dbbd35ab6d24f5adef5e4796810_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_node.pklz
# 171217-19:10:53,856 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_report
# 171217-19:10:53,861 workflow DEBUG:
# 	 Removing files:
# 171217-19:10:53,915 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/result__gunzip_con0.pklz
# 171217-19:10:53,921 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/_report/report.rst
# 171217-19:10:53,929 workflow DEBUG:
# 	 Finished running _gunzip_con0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0
#
# 171217-19:10:53,944 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/result_gunzip_con.pklz
# 171217-19:10:53,950 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/_report/report.rst
# 171217-19:10:53,957 workflow DEBUG:
# 	 Finished running gunzip_con.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con
#
# 171217-19:10:53,963 workflow INFO:
# 	 [Job finished] jobname: gunzip_con.a0 jobid: 2
# 171217-19:10:53,965 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:54,386 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/anat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/anat.mat;/Volumes/myFatDrive/ada_project/workingdir/PPMI/3105/ep2d_RESTING_STATE/anat/zipped/anat.nii.gz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_0xdef88a2df65a317b3c6d10f50c453093_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_node.pklz
# 171217-19:10:54,391 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_report
# 171217-19:10:54,397 workflow DEBUG:
# 	 Removing files:
# 171217-19:10:54,414 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/result_gunzip_struct.pklz
# 171217-19:10:54,420 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/_report/report.rst
# 171217-19:10:54,427 workflow DEBUG:
# 	 Finished running gunzip_struct.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct
#
# 171217-19:10:54,433 workflow INFO:
# 	 [Job finished] jobname: gunzip_struct.a0 jobid: 1
# 171217-19:10:54,435 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-19:10:54,439 workflow INFO:
# 	 Executing: normalize.a0 ID: 3
# 171217-19:10:54,440 workflow DEBUG:
# 	 checking hash locally
# 171217-19:10:54,441 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:10:54,442 workflow DEBUG:
# 	 input: image_to_align
# 171217-19:10:54,443 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/result_gunzip_struct.pklz
# 171217-19:10:54,445 workflow DEBUG:
# 	 output: out_file
# 171217-19:10:54,446 workflow DEBUG:
# 	 setting nodelevel(normalize) input image_to_align = /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_struct/anat.nii
# 171217-19:10:54,448 workflow DEBUG:
# 	 input: apply_to_files
# 171217-19:10:54,449 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/result_gunzip_con.pklz
# 171217-19:10:54,451 workflow DEBUG:
# 	 output: out_file
# 171217-19:10:54,452 workflow DEBUG:
# 	 setting nodelevel(normalize) input apply_to_files = ['/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/gunzip_con/mapflow/_gunzip_con0/rest_mean.nii']
# 171217-19:10:54,455 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:54,456 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_0x280fa3f8bf4e088ea601f158c9b57c87.json
# 171217-19:10:54,458 workflow DEBUG:
# 	 Hash exists False
# 171217-19:10:54,459 workflow DEBUG:
# 	 Finished checking hash
# 171217-19:10:54,460 workflow DEBUG:
# 	 MultiProcPlugin submitting 3
# 171217-19:10:54,469 workflow INFO:
# 	 Executing node normalize.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize
# 171217-19:10:54,479 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:10:54,485 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_0x280fa3f8bf4e088ea601f158c9b57c87.json
# 171217-19:10:54,492 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 171217-19:10:54,498 workflow DEBUG:
# 	 Node hash: 280fa3f8bf4e088ea601f158c9b57c87
# 171217-19:10:54,504 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_0x280fa3f8bf4e088ea601f158c9b57c87_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-19:10:54,512 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize
# 171217-19:10:54,554 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_report/report.rst
# 171217-19:10:54,605 workflow DEBUG:
# 	 Executing node
# 171217-19:10:54,612 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-19:10:54,962 interface DEBUG:
# 	 nodesktop_True
# 171217-19:10:54,969 interface DEBUG:
# 	 nosplash_True
# 171217-19:10:54,974 interface DEBUG:
# 	 single_comp_thread_True
# 171217-19:10:54,979 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-19:10:56,464 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:56,466 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:10:58,471 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:10:58,472 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:00,477 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:00,479 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:02,484 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:02,486 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:04,494 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:04,496 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:06,502 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:06,503 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:08,508 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:08,510 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:10,514 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:10,516 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:12,521 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:12,523 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:14,530 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:14,532 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:15,661 interface DEBUG:
# 	 nodesktop_True
# 171217-19:11:15,699 interface DEBUG:
# 	 nosplash_True
# 171217-19:11:15,719 interface DEBUG:
# 	 single_comp_thread_True
# 171217-19:11:15,733 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-19:11:16,540 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:16,543 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:18,549 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:18,551 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:20,559 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:20,561 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:22,565 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:22,566 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:24,574 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:24,576 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:26,584 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:26,585 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:28,593 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:28,594 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:30,598 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:30,599 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:32,607 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:32,608 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:34,611 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:34,612 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:35,451 interface DEBUG:
# 	 nodesktop_True
# 171217-19:11:35,456 interface DEBUG:
# 	 nosplash_True
# 171217-19:11:35,460 interface DEBUG:
# 	 single_comp_thread_True
# 171217-19:11:35,464 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-19:11:36,614 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:36,615 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:38,622 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:38,623 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:40,626 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:40,628 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:42,634 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:42,635 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:44,642 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:44,643 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:46,651 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:46,652 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:48,659 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:48,660 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:49,10 interface DEBUG:
# 	 nodesktop_True
# 171217-19:11:49,14 interface DEBUG:
# 	 nosplash_True
# 171217-19:11:49,35 interface DEBUG:
# 	 single_comp_thread_True
# 171217-19:11:49,40 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 171217-19:11:50,667 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:50,668 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:52,676 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:52,677 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:54,685 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:54,686 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:56,694 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:56,695 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:11:58,698 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:11:58,700 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:00,703 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:00,704 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:02,711 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:02,712 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:04,718 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:04,719 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:06,725 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:06,727 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:08,732 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:08,734 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:10,736 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:10,738 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:12,742 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:12,743 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:14,746 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:14,747 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:16,752 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:16,753 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:18,756 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:18,757 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:20,760 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:20,761 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:22,763 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:22,764 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:24,771 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:24,772 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:26,775 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:26,776 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:28,778 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:28,779 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:30,782 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:30,783 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:32,790 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:32,791 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:34,795 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:34,796 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:36,799 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:36,800 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:38,807 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:38,808 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:40,812 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:40,813 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:42,820 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:42,821 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:44,824 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:44,826 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:46,830 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:46,831 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:48,837 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:48,838 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:50,845 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:50,846 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:52,853 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:52,854 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:54,857 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:54,858 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:56,860 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:56,861 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:12:58,868 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:12:58,869 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:00,873 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:00,874 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:02,881 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:02,882 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:04,889 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:04,890 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:06,896 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:06,897 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:08,904 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:08,905 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:10,912 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:10,914 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:12,925 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:12,926 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:14,933 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:14,934 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:16,937 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:16,939 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:18,942 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:18,943 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:20,949 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:20,950 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:22,957 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:22,958 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:24,965 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:24,966 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:26,971 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:26,973 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:28,975 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:28,976 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:30,980 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:30,981 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:32,983 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:32,984 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:34,991 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:34,991 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:36,995 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:36,996 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:38,999 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:39,0 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:41,5 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:41,6 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:43,12 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:43,13 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:45,18 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:45,19 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:47,23 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:47,24 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:49,26 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:49,27 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:51,29 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:51,30 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:53,33 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:53,34 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:55,42 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:55,43 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:57,46 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:57,47 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:13:59,53 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:13:59,54 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:01,59 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:01,60 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:03,66 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:03,67 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:05,70 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:05,71 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:07,74 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:07,75 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:09,79 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:09,80 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:11,87 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:11,88 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:13,94 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:13,95 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:15,99 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:15,100 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:17,107 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:17,109 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:19,115 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:19,117 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:21,124 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:21,126 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:23,133 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:23,134 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:25,136 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:25,137 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:27,142 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:27,143 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:29,149 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:29,150 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:31,155 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:31,157 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:33,163 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:33,164 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:35,168 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:35,169 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:37,173 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:37,174 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:39,182 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:39,183 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:41,192 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:41,193 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:43,198 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:43,200 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:45,202 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:45,203 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:47,207 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:47,209 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:49,214 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:49,216 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:51,221 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:51,222 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:53,226 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:53,227 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:55,230 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:55,231 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:57,237 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:57,238 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:14:59,243 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:14:59,244 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:01,247 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:01,248 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:03,252 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:03,253 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:05,259 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:05,260 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:07,264 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:07,265 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:09,267 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:09,268 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:11,270 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:11,271 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:13,276 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:13,278 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:15,281 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:15,282 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:17,285 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:17,286 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:19,292 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:19,293 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:21,297 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:21,298 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:23,302 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:23,303 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:25,307 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:25,308 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:27,313 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:27,314 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:29,316 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:29,317 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:31,320 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:31,321 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:33,328 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:33,329 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:35,332 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:35,333 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:37,335 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:37,336 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:39,340 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:39,341 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:41,348 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:41,349 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:43,355 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:43,355 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:45,362 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:45,363 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:47,366 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:47,367 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:49,370 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:49,371 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:51,378 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:51,379 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:53,382 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:53,383 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:55,389 workflow DEBUG:
# 	 MultiProcPlugin timeout before signal received. Deadlock averted??
# 171217-19:15:55,390 workflow DEBUG:
# 	 Number of pending tasks: 1
# 171217-19:15:55,927 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/rest_mean.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/rest_mean.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/anat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/anat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/TPM.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/TPM.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_0x280fa3f8bf4e088ea601f158c9b57c87_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/pyscript_normalize12.m;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_node.pklz
# 171217-19:15:55,937 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_report
# 171217-19:15:55,943 workflow DEBUG:
# 	 Removing files:
# 171217-19:15:55,965 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/result_normalize.pklz
# 171217-19:15:55,972 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/_report/report.rst
# 171217-19:15:55,994 workflow DEBUG:
# 	 Finished running normalize.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize
#
# 171217-19:15:56,4 workflow INFO:
# 	 [Job finished] jobname: normalize.a0 jobid: 3
# 171217-19:15:56,7 workflow DEBUG:
# 	 Number of pending tasks: 0
# 171217-19:15:56,9 workflow INFO:
# 	 Executing: datasink.a0 ID: 4
# 171217-19:15:56,11 workflow DEBUG:
# 	 checking hash locally
# 171217-19:15:56,12 workflow DEBUG:
# 	 Setting node inputs
# 171217-19:15:56,14 workflow DEBUG:
# 	 input: normalized.@files
# 171217-19:15:56,15 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/result_normalize.pklz
# 171217-19:15:56,19 workflow DEBUG:
# 	 output: normalized_files
# 171217-19:15:56,20 workflow DEBUG:
# 	 setting nodelevel(datasink) input normalized.@files = /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.nii
# 171217-19:15:56,22 workflow DEBUG:
# 	 input: normalized.@image
# 171217-19:15:56,23 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/result_normalize.pklz
# 171217-19:15:56,25 workflow DEBUG:
# 	 output: normalized_image
# 171217-19:15:56,26 workflow DEBUG:
# 	 setting nodelevel(datasink) input normalized.@image = /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.nii
# 171217-19:15:56,27 workflow DEBUG:
# 	 input: normalized.@field
# 171217-19:15:56,29 workflow DEBUG:
# 	 results file: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/result_normalize.pklz
# 171217-19:15:56,31 workflow DEBUG:
# 	 output: deformation_field
# 171217-19:15:56,32 workflow DEBUG:
# 	 setting nodelevel(datasink) input normalized.@field = /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.nii
# 171217-19:15:56,35 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:15:56,36 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_0x760fbc4dad3b1d141ed174197da4175f.json
# 171217-19:15:56,37 workflow DEBUG:
# 	 Hash exists False
# 171217-19:15:56,38 workflow DEBUG:
# 	 Finished checking hash
# 171217-19:15:56,39 workflow DEBUG:
# 	 MultiProcPlugin submitting 4
# 171217-19:15:56,53 workflow INFO:
# 	 Executing node datasink.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink
# 171217-19:15:56,68 workflow DEBUG:
# 	 Found hashfiles: []
# 171217-19:15:56,73 workflow DEBUG:
# 	 Final hashfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_0x760fbc4dad3b1d141ed174197da4175f.json
# 171217-19:15:56,79 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 171217-19:15:56,84 workflow DEBUG:
# 	 Node hash: 760fbc4dad3b1d141ed174197da4175f
# 171217-19:15:56,88 workflow DEBUG:
# 	 /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_0x760fbc4dad3b1d141ed174197da4175f_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 171217-19:15:56,93 workflow DEBUG:
# 	 Creating /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink
# 171217-19:15:56,126 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_report/report.rst
# 171217-19:15:56,163 workflow DEBUG:
# 	 Executing node
# 171217-19:15:56,170 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 171217-19:15:56,181 interface DEBUG:
# 	 key: normalized.@files files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.nii
# 171217-19:15:56,185 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/wrest_mean.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wrest_mean.nii using '_subject_id_' -> ''
# 171217-19:15:56,189 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/wrest_mean.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wrest_mean.nii
# 171217-19:15:56,225 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.nii /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wrest_mean.nii
# 171217-19:15:56,582 interface DEBUG:
# 	 key: normalized.@image files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.nii
# 171217-19:15:56,592 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/wanat.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wanat.nii using '_subject_id_' -> ''
# 171217-19:15:56,601 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/wanat.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wanat.nii
# 171217-19:15:56,608 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.nii /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wanat.nii
# 171217-19:15:56,732 interface DEBUG:
# 	 key: normalized.@field files: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.nii
# 171217-19:15:56,737 interface DEBUG:
# 	 sub.str: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/y_anat.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/y_anat.nii using '_subject_id_' -> ''
# 171217-19:15:56,742 interface INFO:
# 	 sub: /Volumes/myFatDrive/ada_project/output_folder/normalized/_subject_id_3105/y_anat.nii -> /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/y_anat.nii
# 171217-19:15:56,747 interface DEBUG:
# 	 copyfile: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.nii /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/y_anat.nii
# 171217-19:15:57,131 workflow DEBUG:
# 	 Needed files: /Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wrest_mean.nii;/Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wrest_mean.mat;/Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wanat.nii;/Volumes/myFatDrive/ada_project/output_folder/normalized/3105/wanat.mat;/Volumes/myFatDrive/ada_project/output_folder/normalized/3105/y_anat.nii;/Volumes/myFatDrive/ada_project/output_folder/normalized/3105/y_anat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/y_anat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wrest_mean.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.nii;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/normalize/wanat.mat;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_0x760fbc4dad3b1d141ed174197da4175f_unfinished.json;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_inputs.pklz;/Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_node.pklz
# 171217-19:15:57,136 workflow DEBUG:
# 	 Needed dirs: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_report
# 171217-19:15:57,141 workflow DEBUG:
# 	 Removing files:
# 171217-19:15:57,154 workflow DEBUG:
# 	 saved results in /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/result_datasink.pklz
# 171217-19:15:57,159 workflow DEBUG:
# 	 writing post-exec report to /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink/_report/report.rst
# 171217-19:15:57,167 workflow DEBUG:
# 	 Finished running datasink.a0 in dir: /Volumes/myFatDrive/ada_project/workingdir/normflow/_subject_id_3105/datasink
#
# 171217-19:15:57,173 workflow INFO:
# 	 [Job finished] jobname: datasink.a0 jobid: 4
# 171217-19:15:57,175 workflow DEBUG:
# 	 Number of pending tasks: 0

# %% [markdown]
# ### Checking results
# At this point we can show how the obtained images look like.

# %% [markdown]
# In the following, we look at the motion parameters and check wheter the artifact detection algorithm was able to exclude the outliers.

# %% [markdown]
# ## Next steps:
# * Time courses extraction
# * Preprocess all subjects
# * Machine learning
#
# Have a look to the README for more details!
